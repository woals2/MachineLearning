# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats  # 과학용 계산 라이브러리

# %%
# 파일 경로 설정
file_path = "/content/drive/MyDrive/Colab Notebooks/weather.csv"

# CSV 파일 읽기
df = pd.read_csv(file_path)

# 데이터프레임 확인
print(df.head())
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0          NW           30.0         SW  ...          29       1019.7
# 1         ENE           39.0          E  ...          36       1012.4
# 2          NW           85.0          N  ...          69       1009.5
# 3          NW           54.0        WNW  ...          56       1005.5
# 4         SSE           50.0        SSE  ...          49       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1015.0         7         7     14.4     23.6         No      3.6
# 1       1008.4         5         3     17.5     25.7        Yes      3.6
# 2       1007.2         8         7     15.4     20.2        Yes     39.8
# 3       1007.0         2         7     13.5     14.1        Yes      2.8
# 4       1018.5         7         7     11.1     15.4        Yes      0.0
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes
# 4            No
#
# [5 rows x 24 columns]

# %%
#데이터 확인
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# ..          ...       ...      ...      ...       ...          ...       ...
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0            NW           30.0         SW  ...          29       1019.7
# 1           ENE           39.0          E  ...          36       1012.4
# 2            NW           85.0          N  ...          69       1009.5
# 3            NW           54.0        WNW  ...          56       1005.5
# 4           SSE           50.0        SSE  ...          49       1018.3
# ..          ...            ...        ...  ...         ...          ...
# 361         NNW           76.0        SSE  ...          15       1016.1
# 362           N           48.0        NNW  ...          22       1020.0
# 363         ESE           43.0        ENE  ...          47       1024.0
# 364          NW           46.0        SSW  ...          39       1021.0
# 365          NW           78.0         NW  ...          13       1009.6
#
#      Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0         1015.0         7         7     14.4     23.6         No      3.6
# 1         1008.4         5         3     17.5     25.7        Yes      3.6
# 2         1007.2         8         7     15.4     20.2        Yes     39.8
# 3         1007.0         2         7     13.5     14.1        Yes      2.8
# 4         1018.5         7         7     11.1     15.4        Yes      0.0
# ..           ...       ...       ...      ...      ...        ...      ...
# 361       1010.8         1         3     20.4     30.0         No      0.0
# 362       1016.9         0         1     17.2     28.2         No      0.0
# 363       1022.8         3         2     14.5     18.3         No      0.0
# 364       1016.2         6         7     15.8     25.9         No      0.0
# 365       1009.2         1         1     23.8     28.6         No      0.0
#
#      RainTomorrow
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4              No
# ..            ...
# 361            No
# 362            No
# 363            No
# 364            No
# 365            No
#
# [366 rows x 24 columns]

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
# 레이블 확인
plt.hist(y, bins=30, edgecolor='black')
plt.xlabel("Rainfall (mm)")
plt.ylabel("Frequency")
plt.title("Rainfall Distribution")
plt.show()

# %%
# 레이블 갯수 확인 (숫자)
df['Rainfall'].value_counts()
# Out:
# Rainfall
# 0.0     263
# 0.2      17
# 0.6       6
# 0.4       5
# 0.8       5
# 1.0       4
# 4.0       3
# 4.8       3
# 2.0       3
# 1.8       3
# 5.2       3
# 6.6       3
# 3.4       3
# 1.2       3
# 3.6       2
# 6.4       2
# 17.4      2
# 11.0      2
# 3.0       2
# 3.8       2
# 1.6       2
# 16.2      2
# 1.4       2
# 5.4       1
# 4.2       1
# 25.8      1
# 22.6      1
# 39.8      1
# 2.8       1
# 18.8      1
# 14.4      1
# 9.0       1
# 2.2       1
# 12.2      1
# 10.4      1
# 19.8      1
# 2.6       1
# 7.2       1
# 4.4       1
# 6.2       1
# 16.8      1
# 19.2      1
# 7.4       1
# 9.8       1
# 7.6       1
# 8.2       1
# 13.2      1
# Name: count, dtype: int64

# %%
#결측치 확인, 없음
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 데이터 분할
X = df.drop(['Date', 'Location', 'RainToday', 'RainTomorrow', 'RISK_MM', 'Rainfall'], axis=1)
categorical_cols = ['WindGustDir', 'WindDir9am', 'WindDir3pm']
X = pd.get_dummies(X, columns=categorical_cols)


y = df['Rainfall']

# %%
# 원-핫 엔코딩
Y = pd.get_dummies(y).values

# %%
X
# Out:
#      MinTemp  MaxTemp  Evaporation  Sunshine  WindGustSpeed  WindSpeed9am  \
# 0        8.0     24.3          3.4       6.3           30.0           6.0
# 1       14.0     26.9          4.4       9.7           39.0           4.0
# 2       13.7     23.4          5.8       3.3           85.0           6.0
# 3       13.3     15.5          7.2       9.1           54.0          30.0
# 4        7.6     16.1          5.6      10.6           50.0          20.0
# ..       ...      ...          ...       ...            ...           ...
# 361      9.0     30.7          7.6      12.1           76.0           7.0
# 362      7.1     28.4         11.6      12.7           48.0           2.0
# 363     12.5     19.9          8.4       5.3           43.0          11.0
# 364     12.5     26.9          5.0       7.1           46.0           6.0
# 365     12.3     30.2          6.0      12.6           78.0          31.0
#
#      WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  ...  WindDir3pm_NNW  \
# 0              20           68           29       1019.7  ...           False
# 1              17           80           36       1012.4  ...           False
# 2               6           82           69       1009.5  ...           False
# 3              24           62           56       1005.5  ...           False
# 4              28           68           49       1018.3  ...           False
# ..            ...          ...          ...          ...  ...             ...
# 361            50           38           15       1016.1  ...           False
# 362            19           45           22       1020.0  ...            True
# 363             9           63           47       1024.0  ...           False
# 364            28           69           39       1021.0  ...           False
# 365            35           43           13       1009.6  ...           False
#
#      WindDir3pm_NW  WindDir3pm_S  WindDir3pm_SE  WindDir3pm_SSE  \
# 0             True         False          False           False
# 1            False         False          False           False
# 2            False         False          False           False
# 3            False         False          False           False
# 4            False         False          False           False
# ..             ...           ...            ...             ...
# 361           True         False          False           False
# 362          False         False          False           False
# 363          False         False          False           False
# 364          False         False          False           False
# 365          False         False          False           False
#
#      WindDir3pm_SSW  WindDir3pm_SW  WindDir3pm_W  WindDir3pm_WNW  \
# 0             False          False         False           False
# 1             False          False          True           False
# 2             False          False         False           False
# 3             False          False          True           False
# 4             False          False         False           False
# ..              ...            ...           ...             ...
# 361           False          False         False           False
# 362           False          False         False           False
# 363           False          False         False           False
# 364           False          False         False            True
# 365           False          False         False            True
#
#      WindDir3pm_WSW
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 361           False
# 362           False
# 363           False
# 364           False
# 365           False
#
# [328 rows x 63 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, shuffle=True, random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (262, 63) (262,)
# (66, 63) (66,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 27.543844095991123
# 평균제곱근오차 27.543844095991123
# 평균제곱근오차 27.54384409599112

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 48.2690909090909

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 31.03986387878787

# %%
from sklearn.svm import SVR

model = SVR(kernel='linear')
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 31.722459873672975
